# %%
import os
import sys
from dotenv import load_dotenv, find_dotenv

# %%
import json

# %%
import pandas as pd
import numpy as np

# %%
DATA_FOLDER_PATH = os.path.join(os.path.dirname(os.getcwd()), "data","deploy2")
DEPLOY1_FOLDER_PATH = os.path.join(os.path.dirname(os.getcwd()), "data","deploy1")
SCAN_FOLDER_PATH = os.path.join(os.path.dirname(os.getcwd()), "streamlit","scan")
STREAMLIT_FOLDER_PATH = os.path.join(os.path.dirname(os.getcwd()), "streamlit")

# %%
players = pd.read_pickle(os.path.join(STREAMLIT_FOLDER_PATH,"players.pkl"))

# %%
players.head()
# Out:
#                                       burners  \
# 0  0x3FE255c4d125290977f5583F849040416CCE938c
# 1  0x7141Bd2E038cc89E8D3c4dA6d87740949dF40212
# 2  0x44a1Eb48c93B6297Dbf43B8896A2e793610B756d
# 3  0x5e2cD87941B43d8091C84e9B032101a3215c63E2
# 4  0xc279E1928E052aEA00b6435A80D61430472555c5
#
#                                  burnerParent  totalWins  totalLosses  \
# 0  0xE830F2785E2C4abbE8B9BCA738Efd6DE50D0CB86       33.0         58.0
# 1  0x7A1f11FF4d3a14452090b28Ea09Fe40F0cA94f81       16.0         41.0
# 2  0x512F753e1bF0b846de1FCdEbCEecab1CEa603E6d       27.0         27.0
# 3  0x14576E03188F7DF78c62B8F9F5B4CA1EBF16a219       14.0         28.0
# 4  0xD4F6D68c0A0D202ADcFf35a38d577B7b96B956af        7.0         24.0
#
#    totalGasEarned  totalGasLost  totalGames  totalRevenue
# 0          3.3640          5.80        91.0       -2.4360
# 1          2.1240          4.10        57.0       -1.9760
# 2          2.7880          2.70        54.0        0.0880
# 3          3.3796          5.11        42.0       -1.7304
# 4          0.9660          4.26        31.0       -3.2940

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19304 entries, 0 to 19303
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   burners         19304 non-null  object
#  1   burnerParent    19304 non-null  object
#  2   totalWins       19304 non-null  float64
#  3   totalLosses     19304 non-null  float64
#  4   totalGasEarned  19304 non-null  float64
#  5   totalGasLost    19304 non-null  float64
#  6   totalGames      19304 non-null  float64
#  7   totalRevenue    19304 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 1.2+ MB

# %%
deploy1 = pd.read_pickle(os.path.join(DEPLOY1_FOLDER_PATH,"players.pkl"))

# %%
deploy1.head()
# Out:
#                                       burners  \
# 0  0x24bF54A5Ce74e589Bc192518d76b75959886346d
# 1  0xfE3e6ab5d787F4099478Bbe811a740d903E219fb
# 2  0x100b782936498F640c8Df54ab57bfd2186F0f002
# 3  0x16f6AfF7A2D84B802b2ddF0F0AeD49033B69F4f9
# 4  0x6cF9E3ADF2c0FaB32C6f19c112dB62239DeBc049
#
#                                  burnerParent  totalWins  totalLosses  \
# 0  0xB8eb412990236ebb933675C8b5C4cc9812B69dED        2.0          3.0
# 1  0x0000000000000000000000000000000000000000        1.0          4.0
# 2  0x4EE6a67a9DDeD0c4c74FD9Ee4E2D83D03bf50A94        0.0          5.0
# 3  0x0000000000000000000000000000000000000000        1.0          3.0
# 4  0x7C898Dd66e27Cc82C87Ddbe0dB3093308DaF27fd        2.0          2.0
#
#    totalGasEarned  totalGasLost  totalGames  totalRevenue
# 0           0.584           0.3         5.0         0.284
# 1           0.584           0.5         5.0         0.084
# 2           0.000           0.5         5.0        -0.500
# 3           0.096           0.3         4.0        -0.204
# 4           0.584           0.2         4.0         0.384

# %%
deploy1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   burners         177 non-null    object
#  1   burnerParent    177 non-null    object
#  2   totalWins       177 non-null    float64
#  3   totalLosses     177 non-null    float64
#  4   totalGasEarned  177 non-null    float64
#  5   totalGasLost    177 non-null    float64
#  6   totalGames      177 non-null    float64
#  7   totalRevenue    177 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 11.2+ KB

# %%
finalPlayers = pd.concat([players, deploy1],ignore_index=True)

# %%
finalPlayers = finalPlayers.sort_values(["burnerParent","totalGames"], ascending = [False, False])
finalPlayers.reset_index(drop=True,inplace=True)
print(finalPlayers.info())
finalPlayers.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19481 entries, 0 to 19480
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   burners         19481 non-null  object
#  1   burnerParent    19481 non-null  object
#  2   totalWins       19481 non-null  float64
#  3   totalLosses     19481 non-null  float64
#  4   totalGasEarned  19481 non-null  float64
#  5   totalGasLost    19481 non-null  float64
#  6   totalGames      19481 non-null  float64
#  7   totalRevenue    19481 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 1.2+ MB
# None
#                                       burners  \
# 0  0xeedb9220C43f29Bd807Fd2c092c0EFA841F67ED4
# 1  0xCb75970cd756b4a61011e0769f2299529d7ca1C6
# 2  0x4eFCE49177BA93E0d103C2e97f9446eEc67Ebd1b
# 3  0x37Bd449B9e6Cfde37d2242d83D3164a25d3d8132
# 4  0x181013F3dDF8F6Cc041c2da48055916d2916aF2e
# 5  0xABDc48DF1EF1f7D6E8C7967e745a5336315d73f2
# 6  0x8FC103DF3b45237e310315c1b83d0d76cbDfF0C7
# 7  0x545ad30803a2053ebe44E7f6a6D0d8A46BB91ac9
# 8  0x6c159A2131f7239BC50e56a140Ccd3729b2887C4
# 9  0x22480aC8D37C43cd9Ed2eB6c0bCbe97175FcC3cC
#
#                                  burnerParent  totalWins  totalLosses  \
# 0  0xfff069C7de69b4433050E7AaeaB4BB198541DF56        1.0          4.0
# 1  0xffb0A17E69CB382175503cfe0B029b179658a06A        1.0          1.0
# 2  0xffC43AAF9c2757BedF25155735B7d886093279bB        0.0          1.0
# 3  0xff8FBcf1Cb1cBa9C2714894332251808456cCa90        0.0          1.0
# 4  0xff77d744410d38Ec7DF31569eE0489722FF39929        0.0          1.0
# 5  0xff725A2DA2C9a82F0F0da53b19d1cf02488c9a64        1.0          3.0
# 6  0xff71512c84096F55cdF5C5f3D3c6AcE99b56feF0        0.0          1.0
# 7  0xff66a8910B66CD4aE51002B1508E824665c5D28c        3.0          3.0
# 8  0xff591319f7A888395375295A04d0e6be973BB8C8        0.0          1.0
# 9  0xff3b4F136aCc99a97d0b48dB69D402123266a915        0.0          1.0
#
#    totalGasEarned  totalGasLost  totalGames  totalRevenue
# 0           0.292           1.3         5.0        -1.008
# 1           0.096           0.1         2.0        -0.004
# 2           0.000           0.1         1.0        -0.100
# 3           0.000           0.1         1.0        -0.100
# 4           0.000           0.1         1.0        -0.100
# 5           0.096           0.4         4.0        -0.304
# 6           0.000           0.1         1.0        -0.100
# 7           4.172           3.1         6.0         1.072
# 8           0.000           0.1         1.0        -0.100
# 9           0.000           0.1         1.0        -0.100

# %%
#19481 - 1599 (those with no parent) = 17882

# %%
# Out:
#                                           burners  \
# 0      0xeedb9220C43f29Bd807Fd2c092c0EFA841F67ED4
# 1      0xCb75970cd756b4a61011e0769f2299529d7ca1C6
# 2      0x4eFCE49177BA93E0d103C2e97f9446eEc67Ebd1b
# 3      0x37Bd449B9e6Cfde37d2242d83D3164a25d3d8132
# 4      0x181013F3dDF8F6Cc041c2da48055916d2916aF2e
# ...                                           ...
# 17877  0x4Ee5975FF8a66d8FA591CaE7DA2e684361070854
# 17878  0x6455961d84F418a5F4574529FAcf6532d0291798
# 17879  0x1E5570ab680Fa67434954e973E0c8B695c255Cb8
# 17880  0x8c49f23f54b6307f8B5b0D49B288003C2845b2F3
# 17881  0xC4d572dfe8B6D369d7F5bF40e78AAB012b5d1a67
#
#                                      burnerParent  totalWins  totalLosses  \
# 0      0xfff069C7de69b4433050E7AaeaB4BB198541DF56        1.0          4.0
# 1      0xffb0A17E69CB382175503cfe0B029b179658a06A        1.0          1.0
# 2      0xffC43AAF9c2757BedF25155735B7d886093279bB        0.0          1.0
# 3      0xff8FBcf1Cb1cBa9C2714894332251808456cCa90        0.0          1.0
# 4      0xff77d744410d38Ec7DF31569eE0489722FF39929        0.0          1.0
# ...                                           ...        ...          ...
# 17877  0x000025B47899B3fc97383a65510C8e84389B1490        1.0          7.0
# 17878  0x00000E0e2E6298505A639A340845F60a0eeA8528        0.0          1.0
# 17879  0x000000a584697755A0378444f34FEc06229B7E38        2.0          2.0
# 17880  0x0000001089167600c25258Da29d2e2c857ec1689        1.0          0.0
# 17881  0x000000006F457c0f8F560333d9c2877287d92a92        0.0          1.0
#
#        totalGasEarned  totalGasLost  totalGames  totalRevenue
# 0               0.292           1.3         5.0        -1.008
# 1               0.096           0.1         2.0        -0.004
# 2               0.000           0.1         1.0        -0.100
# 3               0.000           0.1         1.0        -0.100
# 4               0.000           0.1         1.0        -0.100
# ...               ...           ...         ...           ...
# 17877           0.194           0.7         8.0        -0.506
# 17878           0.000           0.1         1.0        -0.100
# 17879           0.486           0.2         4.0         0.286
# 17880           1.940           0.0         1.0         1.940
# 17881           0.000           0.1         1.0        -0.100
#
# [17882 rows x 8 columns]

# %%
finalPlayersWithParentBurner = finalPlayers[finalPlayers["burnerParent"] !="0x0000000000000000000000000000000000000000"]
print(finalPlayersWithParentBurner.info())
finalPlayersWithParentBurner.sort_values(by=["burnerParent", "totalGames"],ascending=[False,False],inplace=True)
finalPlayersWithParentBurner.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17882 entries, 0 to 17881
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   burners         17882 non-null  object
#  1   burnerParent    17882 non-null  object
#  2   totalWins       17882 non-null  float64
#  3   totalLosses     17882 non-null  float64
#  4   totalGasEarned  17882 non-null  float64
#  5   totalGasLost    17882 non-null  float64
#  6   totalGames      17882 non-null  float64
#  7   totalRevenue    17882 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 1.2+ MB
# None
# /tmp/ipykernel_130/3616447075.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finalPlayersWithParentBurner.sort_values(by=["burnerParent", "totalGames"],ascending=[False,False],inplace=True)
#                                       burners  \
# 0  0xeedb9220C43f29Bd807Fd2c092c0EFA841F67ED4
# 1  0xCb75970cd756b4a61011e0769f2299529d7ca1C6
# 2  0x4eFCE49177BA93E0d103C2e97f9446eEc67Ebd1b
# 3  0x37Bd449B9e6Cfde37d2242d83D3164a25d3d8132
# 4  0x181013F3dDF8F6Cc041c2da48055916d2916aF2e
# 5  0xABDc48DF1EF1f7D6E8C7967e745a5336315d73f2
# 6  0x8FC103DF3b45237e310315c1b83d0d76cbDfF0C7
# 7  0x545ad30803a2053ebe44E7f6a6D0d8A46BB91ac9
# 8  0x6c159A2131f7239BC50e56a140Ccd3729b2887C4
# 9  0x22480aC8D37C43cd9Ed2eB6c0bCbe97175FcC3cC
#
#                                  burnerParent  totalWins  totalLosses  \
# 0  0xfff069C7de69b4433050E7AaeaB4BB198541DF56        1.0          4.0
# 1  0xffb0A17E69CB382175503cfe0B029b179658a06A        1.0          1.0
# 2  0xffC43AAF9c2757BedF25155735B7d886093279bB        0.0          1.0
# 3  0xff8FBcf1Cb1cBa9C2714894332251808456cCa90        0.0          1.0
# 4  0xff77d744410d38Ec7DF31569eE0489722FF39929        0.0          1.0
# 5  0xff725A2DA2C9a82F0F0da53b19d1cf02488c9a64        1.0          3.0
# 6  0xff71512c84096F55cdF5C5f3D3c6AcE99b56feF0        0.0          1.0
# 7  0xff66a8910B66CD4aE51002B1508E824665c5D28c        3.0          3.0
# 8  0xff591319f7A888395375295A04d0e6be973BB8C8        0.0          1.0
# 9  0xff3b4F136aCc99a97d0b48dB69D402123266a915        0.0          1.0
#
#    totalGasEarned  totalGasLost  totalGames  totalRevenue
# 0           0.292           1.3         5.0        -1.008
# 1           0.096           0.1         2.0        -0.004
# 2           0.000           0.1         1.0        -0.100
# 3           0.000           0.1         1.0        -0.100
# 4           0.000           0.1         1.0        -0.100
# 5           0.096           0.4         4.0        -0.304
# 6           0.000           0.1         1.0        -0.100
# 7           4.172           3.1         6.0         1.072
# 8           0.000           0.1         1.0        -0.100
# 9           0.000           0.1         1.0        -0.100

# %%
# output FinalPlayersWithBurners
finalPlayersWithParentBurner.to_pickle("finalWithParents06102023.pkl")

# %%
finalPlayersWithParentBurner.to_csv("finalWithParents06102023.csv",index=False)

# %%
# get totals for parent burner
parentBurnerStats = finalPlayersWithParentBurner.groupby("burnerParent")[["totalWins","totalLosses", "totalGasEarned", "totalGasLost", "totalGames", "totalRevenue"
                                                                         ]].sum().reset_index()
print(parentBurnerStats.info())
parentBurnerStats.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17587 entries, 0 to 17586
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   burnerParent    17587 non-null  object
#  1   totalWins       17587 non-null  float64
#  2   totalLosses     17587 non-null  float64
#  3   totalGasEarned  17587 non-null  float64
#  4   totalGasLost    17587 non-null  float64
#  5   totalGames      17587 non-null  float64
#  6   totalRevenue    17587 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 961.9+ KB
# None
#                                  burnerParent  totalWins  totalLosses  \
# 0  0x000000006F457c0f8F560333d9c2877287d92a92        0.0          1.0
# 1  0x0000001089167600c25258Da29d2e2c857ec1689        1.0          0.0
# 2  0x000000a584697755A0378444f34FEc06229B7E38        2.0          2.0
# 3  0x00000E0e2E6298505A639A340845F60a0eeA8528        0.0          1.0
# 4  0x000025B47899B3fc97383a65510C8e84389B1490        1.0          7.0
# 5  0x00043607fA39C35d613fA48A17C7ED1Afd57BBF6        1.0          1.0
# 6  0x000a4311A2B5A3917a747080a812128d945BF422        0.0          3.0
# 7  0x002049cC696e8D70502AA52f99AC22Fa5E9A729E        1.0          0.0
# 8  0x002E48A87EA74a43FdD8Fa4b6461c88afA1775DE        0.0          1.0
# 9  0x002a28aE8FeBcB6486E400ab0c5DD1800f543036        2.0          1.0
#
#    totalGasEarned  totalGasLost  totalGames  totalRevenue
# 0           0.000           0.1         1.0        -0.100
# 1           1.940           0.0         1.0         1.940
# 2           0.486           0.2         4.0         0.286
# 3           0.000           0.1         1.0        -0.100
# 4           0.194           0.7         8.0        -0.506
# 5           0.194           0.1         2.0         0.094
# 6           0.000           0.3         3.0        -0.300
# 7           0.194           0.0         1.0         0.194
# 8           0.000           0.1         1.0        -0.100
# 9           0.584           0.1         3.0         0.484

# %%
complete1Games = parentBurnerStats[parentBurnerStats["totalGames"]>0]
complete1Games.to_csv("complete1Games06102023.csv", index=False)

# %%
complete3Games = parentBurnerStats[parentBurnerStats["totalGames"]>2]
complete3Games.to_csv("complete3Games06102023.csv", index=False)

# %%
totalWins1Games = parentBurnerStats[parentBurnerStats["totalWins"]>0]
totalWins1Games.to_csv("totalWins1orMore06102023.csv", index=False)

# %%
countUnique = finalPlayersWithParentBurner.groupby("burnerParent")["burners"].count().to_frame().reset_index().sort_values(by="burners",ascending=False)
countUnique
# Out:
#                                      burnerParent  burners
# 6475   0x5c1115B1b81df25FB220Aac2c29EDCfE55419ff7        5
# 577    0x08d0c6Da76BeD1887DEf74537805888B475d31D7        3
# 9181   0x873eABb2c1F6a94Dd249edC1cd78cC685f750b22        3
# 10788  0x9d52F776bfF8f8529a56F6c8E67D370E9478Bbf1        3
# 16750  0xe74098c910594c9dad2944F8edFA9Dc31fFD44Fe        3
# ...                                           ...      ...
# 5910   0x563E3BEB8aa9730ea46466BFA5989E5464cD2aAA        1
# 5911   0x564661e9b6607248E99884fAfB6473EB5cCC80E6        1
# 5912   0x564E8308A94107B177a175226E0CA4e8E1234Dd2        1
# 5913   0x564b2064BA7fF4CA1d98F441d1ea7fD612810e11        1
# 17586  0xfff069C7de69b4433050E7AaeaB4BB198541DF56        1
#
# [17587 rows x 2 columns]
